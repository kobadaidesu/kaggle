# %% [markdown]
# # CatBoost + Optuna ハイパーパラメータチューニング
# 変数名を統一して整理したバージョン

# %%
# インポート
import numpy as np
import pandas as pd
import optuna
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score
from collections import Counter
import warnings
import os
warnings.filterwarnings("ignore")

# ランダムシード
RANDOM_STATE = 42

print("ライブラリのインポート完了")
# Out:
# ライブラリのインポート完了

# %%
# データ読み込み
train_raw = pd.read_csv("../input/train.csv", skipinitialspace=True)
test_raw = pd.read_csv("../input/test.csv", skipinitialspace=True)

# 文字列列を一括でstripし、空白のみをNaNに
str_cols = train_raw.select_dtypes(include=["object"]).columns
train_raw[str_cols] = (train_raw[str_cols]
                .apply(lambda s: s.str.strip())
                .replace(r"^\s*$", np.nan, regex=True))

str_cols_test = test_raw.select_dtypes(include=["object"]).columns
test_raw[str_cols_test] = (test_raw[str_cols_test]
                .apply(lambda s: s.str.strip())
                .replace(r"^\s*$", np.nan, regex=True))

print(f"Train shape: {train_raw.shape}")
print(f"Test shape: {test_raw.shape}")
print(f"\nTrain columns: {train_raw.columns.tolist()}")
# Out:
# Train shape: (891, 12)
# Test shape: (418, 11)
#
# Train columns: ['PassengerId', 'Perished', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# 外れ値検出関数
def detect_outliers(df, features):
    outlier_indices = []
    for c in features:
        Q1 = np.percentile(df[c], 25)
        Q3 = np.percentile(df[c], 75)
        IQR = Q3 - Q1
        outlier_step = IQR * 1.5
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        outlier_indices.extend(outlier_list_col)
    
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items() if v > 2)
    return multiple_outliers

# 外れ値削除
outlier_idx = detect_outliers(train_raw, ["Age", "SibSp", "Parch", "Fare"])
train_raw = train_raw.drop(outlier_idx, axis=0).reset_index(drop=True)

print(f"外れ値削除後のTrain shape: {train_raw.shape}")
print(f"削除された行数: {len(outlier_idx)}")
# Out:
# 外れ値削除後のTrain shape: (881, 12)
# 削除された行数: 10

# %%
# trainとtestを結合
train_len = len(train_raw)
df_combined = pd.concat([train_raw, test_raw], axis=0).reset_index(drop=True)

print(f"結合後のデータサイズ: {df_combined.shape}")
print(f"Train length: {train_len}")
# Out:
# 結合後のデータサイズ: (1299, 12)
# Train length: 881

# %%
# 欠損値処理
print("欠損値処理前:")
print(df_combined.isnull().sum())

# Embarked
df_combined["Embarked"] = df_combined["Embarked"].fillna("C")

# Fare
df_combined["Fare"] = df_combined["Fare"].fillna(np.mean(df_combined[df_combined["Pclass"] == 3]["Fare"]))

# Age の欠損値補完
df_combined["Sex_num"] = [1 if i == "male" else 0 for i in df_combined["Sex"]]
index_nan_age = list(df_combined["Age"][df_combined["Age"].isnull()].index)
for i in index_nan_age:
    age_pred = df_combined["Age"][((df_combined["SibSp"] == df_combined.iloc[i]["SibSp"]) &
                              (df_combined["Parch"] == df_combined.iloc[i]["Parch"]) &
                              (df_combined["Pclass"] == df_combined.iloc[i]["Pclass"]))].median()
    age_med = df_combined["Age"].median()
    if not np.isnan(age_pred):
        df_combined["Age"].iloc[i] = age_pred
    else:
        df_combined["Age"].iloc[i] = age_med

print("\n欠損値処理後:")
print(df_combined.isnull().sum())
# Out:
# 欠損値処理前:
# PassengerId       0
# Perished        418
# Pclass            0
# Name              0
# Sex               0
# Age             256
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1007
# Embarked          2
# dtype: int64
#
# 欠損値処理後:
# PassengerId       0
# Perished        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1007
# Embarked          0
# Sex_num           0
# dtype: int64

# %%
# Pclass を One-Hot Encoding
df_combined = pd.get_dummies(df_combined, columns=["Pclass"], prefix="Pclass")

print(f"Pclass One-Hot Encoding後のカラム数: {len(df_combined.columns)}")
print(f"追加されたカラム: {[col for col in df_combined.columns if 'Pclass' in col]}")
# Out:
# Pclass One-Hot Encoding後のカラム数: 15
# 追加されたカラム: ['Pclass_1', 'Pclass_2', 'Pclass_3']

# %%
# Title抽出
df_combined["Title"] = [i.split(".")[0].split(",")[-1].strip() for i in df_combined["Name"]]
df_combined["Title"] = df_combined["Title"].replace(["Lady", "the Countess", "Capt", "Col", "Don", "Dr", "Major", "Rev", "Sir", "Jonkheer", "Dona"], "other")
df_combined["Title"] = [0 if i == "Master" else 1 if i in ["Miss", "Ms", "Mlle", "Mrs"] else 2 if i == "Mr" else 3 for i in df_combined["Title"]]

# 家族サイズ
df_combined["Fsize"] = df_combined["SibSp"] + df_combined["Parch"] + 1
df_combined["family_size"] = [1 if i < 5 else 0 for i in df_combined["Fsize"]]

print("特徴量エンジニアリング完了")
print(f"Title の分布:\n{df_combined['Title'].value_counts()}")
# Out:
# 特徴量エンジニアリング完了
# Title の分布:
# Title
# 2    753
# 1    456
# 0     60
# 3     30
# Name: count, dtype: int64

# %%
# One-Hot Encoding
df_combined = pd.get_dummies(df_combined, columns=["family_size", "Embarked"])

# Ticket処理
tickets = []
for i in list(df_combined.Ticket):
    if not i.isdigit():
        tickets.append(i.replace(".", "").replace("/", "").strip().split(" ")[0])
    else:
        tickets.append("x")
df_combined["Ticket"] = tickets
df_combined = pd.get_dummies(df_combined, columns=["Ticket"], prefix="T")

# Sex One-Hot
df_combined["Sex"] = df_combined["Sex_num"]
df_combined = pd.get_dummies(df_combined, columns=["Sex"])

# Title One-Hot
df_combined = pd.get_dummies(df_combined, columns=["Title"])

print(f"One-Hot Encoding後のカラム数: {len(df_combined.columns)}")
# Out:
# One-Hot Encoding後のカラム数: 61

# %%
# 不要なカラムを削除
drop_cols = ["PassengerId", "Cabin", "Name", "Sex_num"]
df_combined = df_combined.drop(labels=drop_cols, axis=1)

print(f"カラム削除後のサイズ: {df_combined.shape}")
print(f"\n残っているカラム: {df_combined.columns.tolist()[:10]}...")
# Out:
# カラム削除後のサイズ: (1299, 57)
#
# 残っているカラム: ['Perished', 'Age', 'SibSp', 'Parch', 'Fare', 'Pclass_1', 'Pclass_2', 'Pclass_3', 'Fsize', 'family_size_0']...

# %%
# trainとtestに分割
train_processed = df_combined[:train_len].copy()
test_processed = df_combined[train_len:].copy()

# インデックスをリセット（重要！）
train_processed = train_processed.reset_index(drop=True)
test_processed = test_processed.reset_index(drop=True)

# 特徴量とターゲットに分割
X_train_full = train_processed.drop(labels=["Perished"], axis=1)
y_train_full = train_processed["Perished"]
X_test_final = test_processed.drop(labels=["Perished"], axis=1)

print(f"X_train_full shape: {X_train_full.shape}")
print(f"y_train_full shape: {y_train_full.shape}")
print(f"X_test_final shape: {X_test_final.shape}")
print(f"\nX_train_full type: {type(X_train_full)}")
print(f"y_train_full type: {type(y_train_full)}")
# Out:
# X_train_full shape: (881, 56)
# y_train_full shape: (881,)
# X_test_final shape: (418, 56)
#
# X_train_full type: <class 'pandas.core.frame.DataFrame'>
# y_train_full type: <class 'pandas.core.series.Series'>

# %%
# Optuna目的関数
def objective(trial, X_train_full, y_train_full, n_folds=5):
    """Optuna目的関数: CatBoostのハイパーパラメータをチューニング"""
    
    params = {
        "iterations": trial.suggest_int("iterations", 50, 200),
        "learning_rate": trial.suggest_float("learning_rate", 0.03, 0.1),
        "depth": trial.suggest_int("depth", 3, 5),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 5, 20),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 5.0, 20.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 0.5),
        "random_strength": trial.suggest_float("random_strength", 0.0, 2.0),
        "rsm": trial.suggest_float("rsm", 0.7, 0.9),
        "loss_function": "Logloss",
        "eval_metric": "Logloss",
        "random_state": RANDOM_STATE,
        "verbose": 0,
        "early_stopping_rounds": trial.suggest_int("early_stopping_rounds", 30, 50)
    }
    
    # 5-Fold Cross Validation
    cv = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=RANDOM_STATE)
    scores = []
    
    for train_idx, val_idx in cv.split(X_train_full, y_train_full):
        # .ilocを使ってDataFrameからデータを取得
        X_train_fold = X_train_full.iloc[train_idx]
        X_val_fold = X_train_full.iloc[val_idx]
        y_train_fold = y_train_full.iloc[train_idx]
        y_val_fold = y_train_full.iloc[val_idx]
        
        model = CatBoostClassifier(**params)
        model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=50, verbose=0)
        
        y_pred_proba = model.predict_proba(X_val_fold)[:, 1]
        score = roc_auc_score(y_val_fold, y_pred_proba)
        scores.append(score)
    
    return np.mean(scores)

print("Optuna目的関数を定義しました")
# Out:
# Optuna目的関数を定義しました

# %%
# Optunaでハイパーパラメータチューニング
TUNE_HYPERPARAMETERS = True  # Falseにするとチューニングをスキップ
N_TRIALS = 50  # チューニングの試行回数

if TUNE_HYPERPARAMETERS:
    print("="*60)
    print("Optuna ハイパーパラメータチューニング開始")
    print("="*60)
    print(f"試行回数: {N_TRIALS}")
    print(f"CV Folds: 5")
    print("="*60)
    
    # Optunaスタディの作成
    study = optuna.create_study(
        direction="maximize",  # ROC-AUCを最大化
        sampler=optuna.samplers.TPESampler(seed=RANDOM_STATE)
    )
    
    # 最適化実行
    study.optimize(
        lambda trial: objective(trial, X_train_full, y_train_full, n_folds=5),
        n_trials=N_TRIALS,
        show_progress_bar=True
    )
    
    # 最適なパラメータを取得
    best_params_catboost = study.best_params
    best_params_catboost.update({
        "loss_function": "Logloss",
        "eval_metric": "Logloss",
        "random_state": RANDOM_STATE,
        "verbose": 0
    })
    
    print("\n" + "="*60)
    print("チューニング完了")
    print("="*60)
    print(f"最適なROC-AUC: {study.best_value:.4f}")
    print(f"\n最適なパラメータ:")
    for key, value in study.best_params.items():
        print(f"  {key}: {value}")
    print("="*60)
    
else:
    # デフォルトパラメータを使用
    best_params_catboost = {
        "iterations": 1000,
        "learning_rate": 0.03,
        "depth": 7,
        "l2_leaf_reg": 6.0,
        "bagging_temperature": 0.5,
        "random_strength": 1.0,
        "rsm": 0.9,
        "loss_function": "Logloss",
        "eval_metric": "Logloss",
        "random_state": RANDOM_STATE,
        "verbose": 0
    }
    print("デフォルトパラメータを使用します")
    print(best_params_catboost)
# Out:
# [I 2025-11-11 00:31:58,662] A new study created in memory with name: no-name-538a1583-b7a7-4e81-8e6b-c60d9c8f1734
# ============================================================
# Optuna ハイパーパラメータチューニング開始
# ============================================================
# 試行回数: 50
# CV Folds: 5
# ============================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-11 00:32:00,560] Trial 0 finished with value: 0.8845240950610622 and parameters: {'iterations': 106, 'learning_rate': 0.09655000144869413, 'depth': 5, 'min_data_in_leaf': 14, 'l2_leaf_reg': 7.340279606636548, 'bagging_temperature': 0.07799726016810132, 'random_strength': 0.11616722433639892, 'rsm': 0.8732352291549871, 'early_stopping_rounds': 42}. Best is trial 0 with value: 0.8845240950610622.
# [I 2025-11-11 00:32:03,803] Trial 1 finished with value: 0.8827054726069837 and parameters: {'iterations': 156, 'learning_rate': 0.03144091460070617, 'depth': 5, 'min_data_in_leaf': 18, 'l2_leaf_reg': 8.185086660174143, 'bagging_temperature': 0.09091248360355031, 'random_strength': 0.36680901970686763, 'rsm': 0.7608484485919075, 'early_stopping_rounds': 41}. Best is trial 0 with value: 0.8845240950610622.
# [I 2025-11-11 00:32:05,994] Trial 2 finished with value: 0.8843595720653195 and parameters: {'iterations': 115, 'learning_rate': 0.050386039813862936, 'depth': 4, 'min_data_in_leaf': 7, 'l2_leaf_reg': 9.382169728028273, 'bagging_temperature': 0.18318092164684585, 'random_strength': 0.9121399684340719, 'rsm': 0.8570351922786027, 'early_stopping_rounds': 34}. Best is trial 0 with value: 0.8845240950610622.
# [I 2025-11-11 00:32:08,219] Trial 3 finished with value: 0.882769183106474 and parameters: {'iterations': 127, 'learning_rate': 0.07146901982034298, 'depth': 3, 'min_data_in_leaf': 14, 'l2_leaf_reg': 7.557861855309373, 'bagging_temperature': 0.03252579649263976, 'random_strength': 1.8977710745066665, 'rsm': 0.8931264066149118, 'early_stopping_rounds': 46}. Best is trial 0 with value: 0.8845240950610622.
# [I 2025-11-11 00:32:11,824] Trial 4 finished with value: 0.8788839669404969 and parameters: {'iterations': 95, 'learning_rate': 0.036837047980446874, 'depth': 5, 'min_data_in_leaf': 12, 'l2_leaf_reg': 6.830573522671682, 'bagging_temperature': 0.2475884550556351, 'random_strength': 0.06877704223043679, 'rsm': 0.8818640804157565, 'early_stopping_rounds': 35}. Best is trial 0 with value: 0.8845240950610622.
# [I 2025-11-11 00:32:15,763] Trial 5 finished with value: 0.8841779346804982 and parameters: {'iterations': 150, 'learning_rate': 0.05181977532625877, 'depth': 4, 'min_data_in_leaf': 13, 'l2_leaf_reg': 7.7728168328829055, 'bagging_temperature': 0.4847923138822793, 'random_strength': 1.550265646722229, 'rsm': 0.8878997883128379, 'early_stopping_rounds': 48}. Best is trial 0 with value: 0.8845240950610622.
# [I 2025-11-11 00:32:19,859] Trial 6 finished with value: 0.8877525933920969 and parameters: {'iterations': 140, 'learning_rate': 0.09453119645161819, 'depth': 3, 'min_data_in_leaf': 8, 'l2_leaf_reg': 5.678409333658071, 'bagging_temperature': 0.16266516538163217, 'random_strength': 0.777354579378964, 'rsm': 0.7542698063547791, 'early_stopping_rounds': 47}. Best is trial 6 with value: 0.8877525933920969.
# [I 2025-11-11 00:32:22,825] Trial 7 finished with value: 0.8760377316064041 and parameters: {'iterations': 103, 'learning_rate': 0.04966541567811665, 'depth': 4, 'min_data_in_leaf': 7, 'l2_leaf_reg': 17.032954711310595, 'bagging_temperature': 0.03727532183988541, 'random_strength': 1.9737738732010346, 'rsm': 0.8544489538593315, 'early_stopping_rounds': 34}. Best is trial 6 with value: 0.8877525933920969.
# [I 2025-11-11 00:32:24,604] Trial 8 finished with value: 0.8780231256620896 and parameters: {'iterations': 50, 'learning_rate': 0.08708229999183839, 'depth': 5, 'min_data_in_leaf': 16, 'l2_leaf_reg': 16.569055200289185, 'bagging_temperature': 0.03702232586704518, 'random_strength': 0.7169314570885452, 'rsm': 0.7231738119050259, 'early_stopping_rounds': 48}. Best is trial 6 with value: 0.8877525933920969.
# [I 2025-11-11 00:32:28,587] Trial 9 finished with value: 0.884140208070996 and parameters: {'iterations': 144, 'learning_rate': 0.053162861739685444, 'depth': 3, 'min_data_in_leaf': 9, 'l2_leaf_reg': 9.877749830401205, 'bagging_temperature': 0.36480308916903204, 'random_strength': 1.2751149427104262, 'rsm': 0.8774425485152653, 'early_stopping_rounds': 39}. Best is trial 6 with value: 0.8877525933920969.
# [I 2025-11-11 00:32:32,992] Trial 10 finished with value: 0.8872564010313606 and parameters: {'iterations': 194, 'learning_rate': 0.07823046580326583, 'depth': 3, 'min_data_in_leaf': 5, 'l2_leaf_reg': 13.484196360221048, 'bagging_temperature': 0.18088378301924768, 'random_strength': 0.5353653774247429, 'rsm': 0.7784905784205265, 'early_stopping_rounds': 50}. Best is trial 6 with value: 0.8877525933920969.
# [I 2025-11-11 00:32:41,396] Trial 11 finished with value: 0.8903892086906119 and parameters: {'iterations': 200, 'learning_rate': 0.07963092540476943, 'depth': 3, 'min_data_in_leaf': 5, 'l2_leaf_reg': 13.332530270534361, 'bagging_temperature': 0.18658427617517426, 'random_strength': 0.6145932242336972, 'rsm': 0.794427539257331, 'early_stopping_rounds': 50}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:32:47,132] Trial 12 finished with value: 0.8877313565589334 and parameters: {'iterations': 193, 'learning_rate': 0.09759045380061246, 'depth': 3, 'min_data_in_leaf': 10, 'l2_leaf_reg': 12.474322888309313, 'bagging_temperature': 0.17669806916348027, 'random_strength': 1.0792402136055954, 'rsm': 0.8143705508817527, 'early_stopping_rounds': 45}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:32:50,969] Trial 13 finished with value: 0.8863714497011854 and parameters: {'iterations': 179, 'learning_rate': 0.08446754420503565, 'depth': 3, 'min_data_in_leaf': 5, 'l2_leaf_reg': 13.090876027098643, 'bagging_temperature': 0.3095839387020463, 'random_strength': 0.7221452690929376, 'rsm': 0.7263066021748918, 'early_stopping_rounds': 50}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:32:53,118] Trial 14 finished with value: 0.8768066298894684 and parameters: {'iterations': 73, 'learning_rate': 0.06595957542696604, 'depth': 3, 'min_data_in_leaf': 8, 'l2_leaf_reg': 19.92956173363373, 'bagging_temperature': 0.2561654000250591, 'random_strength': 0.38213350811285196, 'rsm': 0.805103212008605, 'early_stopping_rounds': 44}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:32:57,189] Trial 15 finished with value: 0.8887823299554277 and parameters: {'iterations': 174, 'learning_rate': 0.08807419523603449, 'depth': 4, 'min_data_in_leaf': 11, 'l2_leaf_reg': 11.243056636568305, 'bagging_temperature': 0.13193544566156562, 'random_strength': 1.2228283739304744, 'rsm': 0.7572041612931096, 'early_stopping_rounds': 47}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:00,869] Trial 16 finished with value: 0.8829272101297196 and parameters: {'iterations': 171, 'learning_rate': 0.07771496193532906, 'depth': 4, 'min_data_in_leaf': 20, 'l2_leaf_reg': 11.41290807496114, 'bagging_temperature': 0.11517765087652754, 'random_strength': 1.3142906086551223, 'rsm': 0.824212141118845, 'early_stopping_rounds': 30}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:04,960] Trial 17 finished with value: 0.8877757040634806 and parameters: {'iterations': 174, 'learning_rate': 0.08718957661348156, 'depth': 4, 'min_data_in_leaf': 11, 'l2_leaf_reg': 14.982486868897018, 'bagging_temperature': 0.39793872180099116, 'random_strength': 1.6279874111556634, 'rsm': 0.7845077851297114, 'early_stopping_rounds': 43}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:08,983] Trial 18 finished with value: 0.8848999870080551 and parameters: {'iterations': 200, 'learning_rate': 0.0640460325160123, 'depth': 4, 'min_data_in_leaf': 16, 'l2_leaf_reg': 15.849712905603706, 'bagging_temperature': 0.2507285077111834, 'random_strength': 1.1083171868910289, 'rsm': 0.7461254412569618, 'early_stopping_rounds': 39}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:12,549] Trial 19 finished with value: 0.8847088555095841 and parameters: {'iterations': 162, 'learning_rate': 0.07891527668978446, 'depth': 4, 'min_data_in_leaf': 6, 'l2_leaf_reg': 11.153306338839647, 'bagging_temperature': 0.12241387177154898, 'random_strength': 1.4157080476256607, 'rsm': 0.8307767925850943, 'early_stopping_rounds': 50}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:16,339] Trial 20 finished with value: 0.8882955067857929 and parameters: {'iterations': 184, 'learning_rate': 0.06847824683376258, 'depth': 4, 'min_data_in_leaf': 10, 'l2_leaf_reg': 14.406037957834835, 'bagging_temperature': 0.218368259593598, 'random_strength': 0.9804558839573627, 'rsm': 0.7023241923255106, 'early_stopping_rounds': 37}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:20,330] Trial 21 finished with value: 0.8855673232595791 and parameters: {'iterations': 181, 'learning_rate': 0.06843275695849342, 'depth': 4, 'min_data_in_leaf': 10, 'l2_leaf_reg': 14.533386380714685, 'bagging_temperature': 0.23243014442930335, 'random_strength': 0.9330958928128575, 'rsm': 0.7034716807011537, 'early_stopping_rounds': 36}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:24,595] Trial 22 finished with value: 0.8839876776398633 and parameters: {'iterations': 180, 'learning_rate': 0.06070870073085813, 'depth': 4, 'min_data_in_leaf': 11, 'l2_leaf_reg': 17.75391557415867, 'bagging_temperature': 0.2897783922413389, 'random_strength': 1.2025373602971074, 'rsm': 0.7017524976352829, 'early_stopping_rounds': 37}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:29,075] Trial 23 finished with value: 0.8857404659111351 and parameters: {'iterations': 188, 'learning_rate': 0.0734275853636942, 'depth': 5, 'min_data_in_leaf': 9, 'l2_leaf_reg': 11.400056904964984, 'bagging_temperature': 0.1391466583836603, 'random_strength': 0.49194711128537405, 'rsm': 0.7851812378133256, 'early_stopping_rounds': 32}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:32,863] Trial 24 finished with value: 0.8834894865183586 and parameters: {'iterations': 162, 'learning_rate': 0.0839624430103701, 'depth': 4, 'min_data_in_leaf': 12, 'l2_leaf_reg': 14.29029449913152, 'bagging_temperature': 0.20612638100644604, 'random_strength': 0.8935283142423716, 'rsm': 0.7328976089505967, 'early_stopping_rounds': 38}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:36,755] Trial 25 finished with value: 0.8863710749335411 and parameters: {'iterations': 200, 'learning_rate': 0.05856759904479924, 'depth': 3, 'min_data_in_leaf': 15, 'l2_leaf_reg': 12.197829539092538, 'bagging_temperature': 0.3193781258309391, 'random_strength': 0.6121359310412265, 'rsm': 0.7652503069483778, 'early_stopping_rounds': 48}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:40,053] Trial 26 finished with value: 0.8823130908836522 and parameters: {'iterations': 135, 'learning_rate': 0.08803851064323429, 'depth': 4, 'min_data_in_leaf': 7, 'l2_leaf_reg': 9.977606849783388, 'bagging_temperature': 0.2162943348769601, 'random_strength': 0.2530453787424709, 'rsm': 0.7419144984283942, 'early_stopping_rounds': 41}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:43,983] Trial 27 finished with value: 0.8834681247626472 and parameters: {'iterations': 167, 'learning_rate': 0.07467038741302168, 'depth': 5, 'min_data_in_leaf': 9, 'l2_leaf_reg': 18.10674069393996, 'bagging_temperature': 0.08241310168655014, 'random_strength': 1.6549610752669435, 'rsm': 0.7982087803512968, 'early_stopping_rounds': 46}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:47,357] Trial 28 finished with value: 0.8823701804880975 and parameters: {'iterations': 183, 'learning_rate': 0.09020147761782062, 'depth': 3, 'min_data_in_leaf': 11, 'l2_leaf_reg': 13.802123873620381, 'bagging_temperature': 0.14983298900275147, 'random_strength': 1.1000261211508013, 'rsm': 0.7129506491887843, 'early_stopping_rounds': 44}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:50,786] Trial 29 finished with value: 0.8841488277268092 and parameters: {'iterations': 189, 'learning_rate': 0.09262691842054828, 'depth': 5, 'min_data_in_leaf': 13, 'l2_leaf_reg': 10.789458011806472, 'bagging_temperature': 0.007445667878081097, 'random_strength': 1.4576602564484713, 'rsm': 0.7705782995081828, 'early_stopping_rounds': 42}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:54,357] Trial 30 finished with value: 0.883318717395215 and parameters: {'iterations': 155, 'learning_rate': 0.09928947181803913, 'depth': 4, 'min_data_in_leaf': 5, 'l2_leaf_reg': 15.327525205491938, 'bagging_temperature': 0.28098327663852146, 'random_strength': 0.7870580939847608, 'rsm': 0.7944914981939757, 'early_stopping_rounds': 49}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:33:57,958] Trial 31 finished with value: 0.8857178549299434 and parameters: {'iterations': 174, 'learning_rate': 0.08260307206142144, 'depth': 4, 'min_data_in_leaf': 11, 'l2_leaf_reg': 15.326556394260937, 'bagging_temperature': 0.42446684635733206, 'random_strength': 1.7394634556137538, 'rsm': 0.7768404732314358, 'early_stopping_rounds': 43}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:01,616] Trial 32 finished with value: 0.8846626341668167 and parameters: {'iterations': 168, 'learning_rate': 0.08199276769016262, 'depth': 4, 'min_data_in_leaf': 10, 'l2_leaf_reg': 12.469741582826583, 'bagging_temperature': 0.3632902939644573, 'random_strength': 1.7655663363620488, 'rsm': 0.7880284994739005, 'early_stopping_rounds': 41}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:04,980] Trial 33 finished with value: 0.8810182686734225 and parameters: {'iterations': 174, 'learning_rate': 0.09155377063313903, 'depth': 4, 'min_data_in_leaf': 14, 'l2_leaf_reg': 14.754883679978812, 'bagging_temperature': 0.4870220906435186, 'random_strength': 1.406876162777317, 'rsm': 0.8386660128734839, 'early_stopping_rounds': 46}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:07,760] Trial 34 finished with value: 0.8844392726509565 and parameters: {'iterations': 154, 'learning_rate': 0.07197670787143655, 'depth': 4, 'min_data_in_leaf': 12, 'l2_leaf_reg': 13.283352583879381, 'bagging_temperature': 0.3635574697937454, 'random_strength': 0.992798294796402, 'rsm': 0.7585403115868925, 'early_stopping_rounds': 44}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:10,884] Trial 35 finished with value: 0.8840095390857667 and parameters: {'iterations': 126, 'learning_rate': 0.07916625170378543, 'depth': 5, 'min_data_in_leaf': 18, 'l2_leaf_reg': 16.511228487234423, 'bagging_temperature': 0.19955024443540154, 'random_strength': 1.2215351268416077, 'rsm': 0.8065197958624938, 'early_stopping_rounds': 40}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:14,645] Trial 36 finished with value: 0.8883879494713277 and parameters: {'iterations': 190, 'learning_rate': 0.0874810120265286, 'depth': 4, 'min_data_in_leaf': 13, 'l2_leaf_reg': 8.528651733850886, 'bagging_temperature': 0.4514304467862825, 'random_strength': 1.5770193468242728, 'rsm': 0.8203510044239328, 'early_stopping_rounds': 47}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:18,878] Trial 37 finished with value: 0.8809679248865704 and parameters: {'iterations': 200, 'learning_rate': 0.0420644567321555, 'depth': 4, 'min_data_in_leaf': 14, 'l2_leaf_reg': 8.773889107939604, 'bagging_temperature': 0.10211858721382437, 'random_strength': 0.21312765070608242, 'rsm': 0.8149694174461726, 'early_stopping_rounds': 47}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:22,621] Trial 38 finished with value: 0.8859349703184026 and parameters: {'iterations': 186, 'learning_rate': 0.06799141160117182, 'depth': 3, 'min_data_in_leaf': 15, 'l2_leaf_reg': 6.2296724208275425, 'bagging_temperature': 0.06200377121951221, 'random_strength': 1.5460973517339371, 'rsm': 0.835023547492086, 'early_stopping_rounds': 49}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:26,665] Trial 39 finished with value: 0.8841108512722113 and parameters: {'iterations': 192, 'learning_rate': 0.09534421104239871, 'depth': 5, 'min_data_in_leaf': 13, 'l2_leaf_reg': 8.540912264817443, 'bagging_temperature': 0.445711254914368, 'random_strength': 1.852134467831019, 'rsm': 0.8593239311353437, 'early_stopping_rounds': 47}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:29,091] Trial 40 finished with value: 0.8856908716595712 and parameters: {'iterations': 106, 'learning_rate': 0.074754938404783, 'depth': 3, 'min_data_in_leaf': 8, 'l2_leaf_reg': 6.821572303761199, 'bagging_temperature': 0.13893571651967573, 'random_strength': 0.0029000235855067835, 'rsm': 0.7533390379529489, 'early_stopping_rounds': 33}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:32,630] Trial 41 finished with value: 0.8854181657372429 and parameters: {'iterations': 162, 'learning_rate': 0.08798074719635969, 'depth': 4, 'min_data_in_leaf': 11, 'l2_leaf_reg': 10.470307293546888, 'bagging_temperature': 0.4544798138820275, 'random_strength': 1.5700793773011164, 'rsm': 0.8463056690478908, 'early_stopping_rounds': 45}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:36,605] Trial 42 finished with value: 0.888290759728968 and parameters: {'iterations': 177, 'learning_rate': 0.0862888935295757, 'depth': 4, 'min_data_in_leaf': 13, 'l2_leaf_reg': 11.929584570385297, 'bagging_temperature': 0.3970056625919523, 'random_strength': 1.6626653672091336, 'rsm': 0.8173162530894319, 'early_stopping_rounds': 49}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:39,657] Trial 43 finished with value: 0.8858763816433811 and parameters: {'iterations': 146, 'learning_rate': 0.08197436622724842, 'depth': 4, 'min_data_in_leaf': 13, 'l2_leaf_reg': 7.609169746533025, 'bagging_temperature': 0.4079240904354176, 'random_strength': 1.988603853402834, 'rsm': 0.8116337783190972, 'early_stopping_rounds': 49}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:43,071] Trial 44 finished with value: 0.8885207421398732 and parameters: {'iterations': 195, 'learning_rate': 0.09420679803292181, 'depth': 4, 'min_data_in_leaf': 15, 'l2_leaf_reg': 11.864425676473786, 'bagging_temperature': 0.45823984190935707, 'random_strength': 1.3678308764715463, 'rsm': 0.8232406253323034, 'early_stopping_rounds': 48}. Best is trial 11 with value: 0.8903892086906119.
# [I 2025-11-11 00:34:46,588] Trial 45 finished with value: 0.8913755971297797 and parameters: {'iterations': 193, 'learning_rate': 0.09506831405594864, 'depth': 4, 'min_data_in_leaf': 17, 'l2_leaf_reg': 5.047787629414021, 'bagging_temperature': 0.4638038308274862, 'random_strength': 1.3242076413751969, 'rsm': 0.8268828001642882, 'early_stopping_rounds': 48}. Best is trial 45 with value: 0.8913755971297797.
# [I 2025-11-11 00:34:50,119] Trial 46 finished with value: 0.8897447332653755 and parameters: {'iterations': 192, 'learning_rate': 0.09544245037682368, 'depth': 4, 'min_data_in_leaf': 18, 'l2_leaf_reg': 5.536877300672073, 'bagging_temperature': 0.4911285670968105, 'random_strength': 1.3020899555120788, 'rsm': 0.8612271014702327, 'early_stopping_rounds': 46}. Best is trial 45 with value: 0.8913755971297797.
# [I 2025-11-11 00:34:53,417] Trial 47 finished with value: 0.8865147358637644 and parameters: {'iterations': 195, 'learning_rate': 0.09993037965141154, 'depth': 3, 'min_data_in_leaf': 18, 'l2_leaf_reg': 5.6254590212445965, 'bagging_temperature': 0.4714659555220843, 'random_strength': 1.3360113025635465, 'rsm': 0.8672660326879298, 'early_stopping_rounds': 48}. Best is trial 45 with value: 0.8913755971297797.
# [I 2025-11-11 00:34:56,757] Trial 48 finished with value: 0.8914329365793208 and parameters: {'iterations': 195, 'learning_rate': 0.09590299875724938, 'depth': 4, 'min_data_in_leaf': 17, 'l2_leaf_reg': 5.158499853256037, 'bagging_temperature': 0.4904799129579448, 'random_strength': 1.150147641352516, 'rsm': 0.895915750968767, 'early_stopping_rounds': 45}. Best is trial 48 with value: 0.8914329365793208.
# [I 2025-11-11 00:34:59,226] Trial 49 finished with value: 0.8824461333972936 and parameters: {'iterations': 89, 'learning_rate': 0.09513081609534887, 'depth': 3, 'min_data_in_leaf': 20, 'l2_leaf_reg': 5.29327375727094, 'bagging_temperature': 0.49882714855975313, 'random_strength': 1.1606597814345128, 'rsm': 0.8962332356493151, 'early_stopping_rounds': 45}. Best is trial 48 with value: 0.8914329365793208.
#
# ============================================================
# チューニング完了
# ============================================================
# 最適なROC-AUC: 0.8914
#
# 最適なパラメータ:
#   iterations: 195
#   learning_rate: 0.09590299875724938
#   depth: 4
#   min_data_in_leaf: 17
#   l2_leaf_reg: 5.158499853256037
#   bagging_temperature: 0.4904799129579448
#   random_strength: 1.150147641352516
#   rsm: 0.895915750968767
#   early_stopping_rounds: 45
# ============================================================

# %%
# 最適なパラメータで全データを使って学習
print("\n" + "="*60)
print("最終モデルで学習開始")
print("="*60)

final_model = CatBoostClassifier(**best_params_catboost)
final_model.fit(X_train_full, y_train_full, verbose=100)

# テストデータで予測
y_pred = final_model.predict(X_test_final)

print("="*60)
print("予測完了")
print("="*60)
# Out:
# ============================================================
# 最終モデルで学習開始
# ============================================================
# 0:	learn: 0.6473109	total: 806us	remaining: 157ms
# 100:	learn: 0.3309581	total: 91.9ms	remaining: 85.5ms
# 194:	learn: 0.2755400	total: 181ms	remaining: 0us
# ============================================================
# 予測完了
# ============================================================

# %%
# 最適なパラメータで5-Fold CVのスコアと標準偏差を計算
print("\n" + "="*60)
print("5-Fold CV でスコアと標準偏差を計算")
print("="*60)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
cv_scores = []
cv_accuracies = []

for fold_idx, (train_idx, val_idx) in enumerate(cv.split(X_train_full, y_train_full), 1):
    X_train_fold = X_train_full.iloc[train_idx]
    X_val_fold = X_train_full.iloc[val_idx]
    y_train_fold = y_train_full.iloc[train_idx]
    y_val_fold = y_train_full.iloc[val_idx]
    
    model = CatBoostClassifier(**best_params_catboost)
    model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=50, verbose=0)
    
    # ROC-AUC
    y_pred_proba = model.predict_proba(X_val_fold)[:, 1]
    roc_auc = roc_auc_score(y_val_fold, y_pred_proba)
    cv_scores.append(roc_auc)
    
    # Accuracy
    y_pred_fold = model.predict(X_val_fold)
    acc = accuracy_score(y_val_fold, y_pred_fold)
    cv_accuracies.append(acc)
    
    print(f"Fold {fold_idx}: ROC-AUC = {roc_auc:.4f}, Accuracy = {acc:.4f}")

print("\n" + "="*60)
print("Cross-Validation Results")
print("="*60)
print(f"ROC-AUC Mean: {np.mean(cv_scores):.4f}")
print(f"ROC-AUC Std:  {np.std(cv_scores):.4f}")
print(f"\nAccuracy Mean: {np.mean(cv_accuracies):.4f}")
print(f"Accuracy Std:  {np.std(cv_accuracies):.4f}")
print("="*60)
# Out:
# ============================================================
# 5-Fold CV でスコアと標準偏差を計算
# ============================================================
# Fold 1: ROC-AUC = 0.8762, Accuracy = 0.8192
# Fold 2: ROC-AUC = 0.8760, Accuracy = 0.7784
# Fold 3: ROC-AUC = 0.9333, Accuracy = 0.8636
# Fold 4: ROC-AUC = 0.8905, Accuracy = 0.8352
# Fold 5: ROC-AUC = 0.8811, Accuracy = 0.8750
#
# ============================================================
# Cross-Validation Results
# ============================================================
# ROC-AUC Mean: 0.8914
# ROC-AUC Std:  0.0216
#
# Accuracy Mean: 0.8343
# Accuracy Std:  0.0343
# ============================================================

# %%
# 提出用DataFrameを作成
submission = pd.DataFrame({
    'PassengerId': test_raw['PassengerId'],
    'Perished': y_pred.astype(int)
})

# outputフォルダが存在しない場合は作成
output_dir = '../output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# CSVファイルを保存
submission.to_csv(f'{output_dir}/detaicatcat.csv', index=False)

print("Submission file created successfully!")
print(f"File saved to: {output_dir}/detaicatcat.csv")
print(f"\nFirst few rows of submission:")
print(submission.head(10))
print(f"\nSubmission shape: {submission.shape}")
print(f"Perished distribution:\n{submission['Perished'].value_counts()}")
# Out:
# Submission file created successfully!
# File saved to: ../output/detaicatcat.csv
#
# First few rows of submission:
#    PassengerId  Perished
# 0          892         1
# 1          893         1
# 2          894         1
# 3          895         1
# 4          896         1
# 5          897         1
# 6          898         0
# 7          899         1
# 8          900         0
# 9          901         1
#
# Submission shape: (418, 2)
# Perished distribution:
# Perished
# 1    271
# 0    147
# Name: count, dtype: int64

# %%
# 最適なパラメータで5-Fold CVのスコアと標準偏差を計算
print("\n" + "="*60)
print("5-Fold CV でスコアと標準偏差を計算")
print("="*60)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
cv_scores = []
cv_accuracies = []

for fold_idx, (train_idx, val_idx) in enumerate(cv.split(X_train_full, y_train_full), 1):
    X_train_fold = X_train_full.iloc[train_idx]
    X_val_fold = X_train_full.iloc[val_idx]
    y_train_fold = y_train_full.iloc[train_idx]
    y_val_fold = y_train_full.iloc[val_idx]
    
    model = CatBoostClassifier(**best_params_catboost)
    model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=50, verbose=0)
    
    # ROC-AUC
    y_pred_proba = model.predict_proba(X_val_fold)[:, 1]
    roc_auc = roc_auc_score(y_val_fold, y_pred_proba)
    cv_scores.append(roc_auc)
    
    # Accuracy
    y_pred_fold = model.predict(X_val_fold)
    acc = accuracy_score(y_val_fold, y_pred_fold)
    cv_accuracies.append(acc)
    
    print(f"Fold {fold_idx}: ROC-AUC = {roc_auc:.4f}, Accuracy = {acc:.4f}")

print("\n" + "="*60)
print("Cross-Validation Results")
print("="*60)
print(f"ROC-AUC Mean: {np.mean(cv_scores):.4f}")
print(f"ROC-AUC Std:  {np.std(cv_scores):.4f}")
print(f"\nAccuracy Mean: {np.mean(cv_accuracies):.4f}")
print(f"Accuracy Std:  {np.std(cv_accuracies):.4f}")
print("="*60)
# Out:
# ============================================================
# 5-Fold CV でスコアと標準偏差を計算
# ============================================================
# Fold 1: ROC-AUC = 0.8762, Accuracy = 0.8192
# Fold 2: ROC-AUC = 0.8760, Accuracy = 0.7784
# Fold 3: ROC-AUC = 0.9333, Accuracy = 0.8636
# Fold 4: ROC-AUC = 0.8905, Accuracy = 0.8352
# Fold 5: ROC-AUC = 0.8811, Accuracy = 0.8750
#
# ============================================================
# Cross-Validation Results
# ============================================================
# ROC-AUC Mean: 0.8914
# ROC-AUC Std:  0.0216
#
# Accuracy Mean: 0.8343
# Accuracy Std:  0.0343
# ============================================================

# %%
X_train_full.columns
# Out:
# Index(['Age', 'SibSp', 'Parch', 'Fare', 'Pclass_1', 'Pclass_2', 'Pclass_3',
#        'Fsize', 'family_size_0', 'family_size_1', 'Embarked_C', 'Embarked_Q',
#        'Embarked_S', 'T_A', 'T_A4', 'T_A5', 'T_AQ3', 'T_AQ4', 'T_AS', 'T_C',
#        'T_CA', 'T_CASOTON', 'T_FC', 'T_FCC', 'T_Fa', 'T_LINE', 'T_LP', 'T_PC',
#        'T_PP', 'T_PPP', 'T_SC', 'T_SCA3', 'T_SCA4', 'T_SCAH', 'T_SCOW',
#        'T_SCPARIS', 'T_SCParis', 'T_SOC', 'T_SOP', 'T_SOPP', 'T_SOTONO2',
#        'T_SOTONOQ', 'T_SP', 'T_STONO', 'T_STONO2', 'T_STONOQ', 'T_SWPP',
#        'T_WC', 'T_WEP', 'T_x', 'Sex_0', 'Sex_1', 'Title_0', 'Title_1',
#        'Title_2', 'Title_3'],
#       dtype='object')

# %%
int(submission.head(10))  # 最初の10行
print(submission.shape)     # (418, 2) のような形
print(submission['Perished'].value_counts())  # 0と1の分布
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3239/3440068963.py in <cell line: 0>()
# ----> 1 int(submission.head(10))  # 最初の10行
#       2 print(submission.shape)     # (418, 2) のような形
#       3 print(submission['Perished'].value_counts())  # 0と1の分布
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'DataFrame'

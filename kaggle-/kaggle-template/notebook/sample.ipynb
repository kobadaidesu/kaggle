# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
from experiments.exp000_sample.run import Config

cfg = Config()
cfg
# Out:
# Config(env=EnvConfig(input_dir='/kaggle/input', output_dir='/kaggle/working/output', exp_output_dir='/kaggle/working/output/experiments'), exp=ExpConfig(debug=False, seed=7, learning_rate=0.001, batch_size=32, folds=[0, 1, 2, 3, 4]))

# %%
from pathlib import Path
import os

exp_name = "notebook/tmp"
output_path = Path(cfg.env.output_dir) / exp_name
print(f"{exp_name=}, {output_path=}")
os.makedirs(output_path, exist_ok=True)
# Out:
# exp_name='notebook/tmp', output_path=PosixPath('/kaggle/working/output/notebook/tmp')
